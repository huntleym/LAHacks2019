# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Isaac\Desktop\City_Owned_Property.csv")

# %%
df['Property_C']
# Out:
# 0       Not Classified
# 1       Not Classified
# 2                 OPLA
# 3       Not Classified
# 4       Not Classified
# 5       Not Classified
# 6       Not Classified
# 7       Not Classified
# 8                 OPLA
# 9                 OPLA
# 10      Not Classified
# 11      Not Classified
# 12      Not Classified
# 13      Not Classified
# 14      Not Classified
# 15      Not Classified
# 16      Not Classified
# 17      Not Classified
# 18      Not Classified
# 19      Not Classified
# 20      Not Classified
# 21      Not Classified
# 22      Not Classified
# 23      Not Classified
# 24      Not Classified
# 25      Not Classified
# 26      Not Classified
# 27      Not Classified
# 28      Not Classified
# 29      Not Classified
#              ...
# 1780    Not Classified
# 1781    Not Classified
# 1782    Not Classified
# 1783    Not Classified
# 1784    Not Classified
# 1785    Not Classified
# 1786    Not Classified
# 1787    Not Classified
# 1788    Not Classified
# ...

# %%
def vac_string(s):
    if "vacan" in s.lower():
        return True
    else:
        return False

df[df['Property_C'].map(vac_string) == True]
# Out:
#                X          Y  OBJECTID  FID_  Parcel_Num  \
# 163  -118.442308  34.205684      1164     0  2215017903
# 560  -118.239311  34.048992      1561     0  5161017921
# 564  -118.234817  34.049736      1565     0  5173010900
# 570  -118.231721  34.048666      1571     0  5173023903
# 715  -118.634210  34.197550      1716     0  2028011901
# 717  -118.428678  34.215526      1718     0  2301011901
# 718  -118.345376  34.123450      1719     0  2429022900
# 719  -118.418572  34.299927      1720     0  2513028908
# 721  -118.424820  34.036570      1722     0  4255019900
# 722  -118.422450  34.036930      1723     0  4255019901
# 723  -118.421740  34.037330      1724     0  4255020900
# 724  -118.425150  34.036870      1725     0  4255021900
# 725  -118.411320  34.031170      1726     0  4318033901
# 726  -118.521650  34.056420      1727     0  4422003901
# 728  -118.188830  34.083060      1729     0  5213024900
# 729  -118.188232  34.081879      1730     0  5214009900
# ...

# %%
df = df[['Property_C','Address1','County','City','Latitude','Longitude','Council_Di']]

# %%
df.to_csv(r"C:\Users\Isaac\Desktop\la_vacancies.csv")
